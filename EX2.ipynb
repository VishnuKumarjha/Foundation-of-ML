# %%
import numpy as np
marks = np.array([[78,85,90],
                [45,60,55],
                [88,92,95],
                [30,40,35],
                [65,70,75]])
print(marks)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 import numpy as np
# ----> 2 marks = np.array([[78,85,90],
#       3                 [45,60,55],
#       4                 [88,92,95],
#       5                 [30,40,35],
#       6                 [65,70,75]])
#       7 print(marks)
#
# TypeError: 'list' object is not callable

# %%
# task A1: metadata discovery

# determine the shape of the array
# find the total number of elements
# identitfy the datatype of the elements


# task A2: data indexing and slicing
# extract all marks for second students
# extract all marks for the 3rd sub across all students
# find the specific marks for students 1 in subject 2

# %%
print(np.shape(marks))
print(np.size(marks))
print(np.dtype)


print(marks(0))
print(marks[:2])
print(marks[0, 1])
# Out:
# (5, 3)
# 15
# <class 'numpy.dtype'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       2 print(np.size(marks))
#       3 print(np.dtype)
# ----> 6 print(marks(0))
#       7 print(marks[:2])
#       8 print(marks[0, 1])
#
# TypeError: 'list' object is not callable

# %%
# task B1: mens and Averages 
        # calculate the average marks for each students
# task B2 : filtering top performance
        #identify and display students whose avg marks are>=80
# task B3 : global adjustments
        # the collage decides to add 5 grace marks to every subject for every students update the array using broadcasting
